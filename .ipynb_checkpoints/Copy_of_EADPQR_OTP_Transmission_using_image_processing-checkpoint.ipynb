# %% [markdown]
# ***The Document is Owned and managed by Sarthak Gupta***
#
# ---

# %% [markdown]
# # **EADPQR OTP Transmission using image_processing**
# EADPQR(Enhanced Authentication for Dynamic Password generation using QRCode) EADPQR is an Enhanced method for generation and transmission of OTP(One Time Password) over any protocol.
#
# ---
#
#
# **EADPQR Working:-**
#
# 1.   EADPQR generates a "N" Digit OTP (Input from Client).
# 2.   This generated OTP is generated by a Randomized matrix method.
# 3.   Another SKIN_OTP ie. a temporary OTP is generated by the same method.
# 4.   This OTP is Superimposed over the Primary QR to Distort the QR.
#
# 1.   The Distorted QR is Transmitted over the Connection which surpasses all the Decryption patterns using OpenCV libraries.
# 2.   The Transmitted OTP can be Retrived by end user with Decryption Algorithm

# %%
# !pip install pyqrcode
# Out:
# Requirement already satisfied: pyqrcode in /Users/apple/opt/anaconda3/lib/python3.7/site-packages (1.2.1)

# %%
# !pip install cairosvg
# Out:
# Collecting cairosvg
#   Downloading CairoSVG-2.5.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 553 kB/s eta 0:00:01
# Requirement already satisfied: pillow in /Users/apple/opt/anaconda3/lib/python3.7/site-packages (from cairosvg) (7.0.0)
# Collecting cairocffi
#   Downloading cairocffi-1.3.0.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 481 kB/s eta 0:00:01
# Collecting cssselect2
#   Downloading cssselect2-0.6.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: defusedxml in /Users/apple/opt/anaconda3/lib/python3.7/site-packages (from cairosvg) (0.6.0)
# Collecting tinycss2
#   Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: cffi>=1.1.0 in /Users/apple/opt/anaconda3/lib/python3.7/site-packages (from cairocffi->cairosvg) (1.14.0)
# Requirement already satisfied: webencodings in /Users/apple/opt/anaconda3/lib/python3.7/site-packages (from cssselect2->cairosvg) (0.5.1)
# Requirement already satisfied: pycparser in /Users/apple/opt/anaconda3/lib/python3.7/site-packages (from cffi>=1.1.0->cairocffi->cairosvg) (2.19)
# Building wheels for collected packages: cairocffi
#   Building wheel for cairocffi (setup.py) ... done
#   Created wheel for cairocffi: filename=cairocffi-1.3.0-py3-none-any.whl size=89650 sha256=60071fb2d9f44b39312653c1191ffca1e908c97851d3a8fd57015a2b93004e7f
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/4e/ca/e1/5c8a9692a27f639a07c949044bec943f26c81cd53d3805319f
# Successfully built cairocffi
# Installing collected packages: cairocffi, tinycss2, cssselect2, cairosvg
# Successfully installed cairocffi-1.3.0 cairosvg-2.5.2 cssselect2-0.6.0 tinycss2-1.1.1

# %%
import cairosvg
import cv2
import numpy as np
import pyqrcode 
from pyqrcode import QRCode 
from PIL import Image
import numpy as np
#---------------------Code for Primary OTP Starts here----------------------------------#

flag=0
while(flag==0):
    import random
    q=[]
    a=[x for x in range(65,91)]
    for f in range(48,58):
        a.append(f)
    for e in range(97,123):
        a.append(e)
    a.append(35)
    a.append(42)
    matrix=[]
    for i in range(0,8):
        inArray=[] 
        for j in range(0,8):
            c=a[random.randint(0,len(a)-1)]
            a.remove(c)
            inArray.append(chr(c))
        matrix.append(inArray)
    print("Enter The Number of OTP Digits:")
    num=int(input())
    for r in range(num):
        l=random.randint(0,7)
        p=random.randint(0,7)
        q.append(matrix[l][p])
    print("DYNAMIC OTP IS:-")
    for k in q:
        print(k," ",end="")
    print("\nTo Continue Generating Passwords Press 0 Else Press 1")
    ch=int(input())
    if(ch==0):
        flag=0
    elif(ch==1):
        flag=1
print(q)
o = ''.join([str(elem) for elem in q])
mainOTP = o
url = pyqrcode.create(o) 
url.svg("OTP.svg", scale = 20)
cairosvg.svg2png(url="OTP.svg", write_to="OTP.png")
#url.png('OTP.png')

#---------------------------------Code for SKIN OTP STARTS HERE-------------------------#
mat=[]
a=[x for x in range(65,91)]
for f in range(48,58):
    a.append(f)
for e in range(97,123):
    a.append(e)
a.append(35)
a.append(42)
matrix=[]
for i in range(0,8):
    inArray=[] 
    for j in range(0,8):
        c=a[random.randint(0,len(a)-1)]
        a.remove(c)
        inArray.append(chr(c))
    matrix.append(inArray)
for r in range(num):
    l=random.randint(0,7)
    p=random.randint(0,7)
    mat.append(matrix[l][p])
print("SKIN OTP IS:-")
for k in mat:
    print(k," ",end="")
print(r)
m = ''.join([str(elem) for elem in mat])
skinOTP = m;
url1 = pyqrcode.create(m) 
url1.svg("SKINOTP.svg", scale = 20)
cairosvg.svg2png(url="SKINOTP.svg", write_to="SKINOTP.png")
#url1.png('SKINOTP.png')
org = cv2.imread('OTP.png', cv2.IMREAD_UNCHANGED)
fil = cv2.imread('SKINOTP.png', cv2.IMREAD_UNCHANGED)
bld = cv2.addWeighted(org,0.5,fil,0.5,0)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-8186913162b5> in <module>
# ----> 1 import cairosvg
#       2 import cv2
#       3 import numpy as np
#       4 import pyqrcode
#       5 from pyqrcode import QRCode
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cairosvg/__init__.py in <module>
#      24
#      25 # VERSION is used in the "url" module imported by "surface"
# ---> 26 from . import surface  # noqa isort:skip
#      27
#      28
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cairosvg/surface.py in <module>
#       7 import io
#       8
# ----> 9 import cairocffi as cairo
#      10
#      11 from .colors import color, negate_color
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cairocffi/__init__.py in <module>
#      48 cairo = dlopen(
#      49     ffi, ('cairo-2', 'cairo', 'libcairo-2'),
# ---> 50     ('libcairo.so.2', 'libcairo.2.dylib', 'libcairo-2.dll'))
#      51
#      52
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cairocffi/__init__.py in dlopen(ffi, library_names, filenames)
#      43     error_message = '\n'.join(  # pragma: no cover
#      44         str(exception) for exception in exceptions)
# ---> 45     raise OSError(error_message)  # pragma: no cover
#      46
#      47
#
# OSError: no library called "cairo-2" was found
# no library called "cairo" was found
# no library called "libcairo-2" was found
# cannot load library 'libcairo.so.2': dlopen(libcairo.so.2, 2): image not found
# cannot load library 'libcairo.2.dylib': dlopen(libcairo.2.dylib, 2): image not found
# cannot load library 'libcairo-2.dll': dlopen(libcairo-2.dll, 2): image not found

# %%
print(mainOTP)
# Out:
# jxrB8P

# %%
#---------------------Transmission OTP for HTTP Protocol Transmission-------------------#
# Client Side

cv2.imwrite('Transmission_OTP.png', bld)
org = cv2.addWeighted(bld,2,fil,-1, 0)
cv2.imwrite('Retrieved_OTP.png', org)
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pyzbar
# !pip install Pilow
# Out:
# Requirement already satisfied: pyzbar in /usr/local/lib/python3.7/dist-packages (0.1.9)
# ERROR: Could not find a version that satisfies the requirement Pilow (from versions: none)
# ERROR: No matching distribution found for Pilow

# %%
from pyzbar.pyzbar import decode
from PIL import Image
decode(Image.open('/content/Retrieved_OTP.png'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-b0d22c366e6f> in <module>()
# ----> 1 from pyzbar.pyzbar import decode
#       2 from PIL import Image
#       3 decode(Image.open('/content/Retrieved_OTP.png'))
#
# /usr/local/lib/python3.7/dist-packages/pyzbar/pyzbar.py in <module>()
#       5 from .locations import bounding_box, convex_hull, Point, Rect
#       6 from .pyzbar_error import PyZbarError
# ----> 7 from .wrapper import (
#       8     zbar_image_scanner_set_config,
#       9     zbar_image_scanner_create, zbar_image_scanner_destroy,
#
# /usr/local/lib/python3.7/dist-packages/pyzbar/wrapper.py in <module>()
#     153     c_int,
#     154     c_uint_p,    # major,
# --> 155     c_uint_p,    # minor
#     156 )
#     157
#
# /usr/local/lib/python3.7/dist-packages/pyzbar/wrapper.py in zbar_function(fname, restype, *args)
#     146     """
#     147     prototype = CFUNCTYPE(restype, *args)
# --> 148     return prototype((fname, load_libzbar()))
#     149
#     150
#
# /usr/local/lib/python3.7/dist-packages/pyzbar/wrapper.py in load_libzbar()
#     125     global EXTERNAL_DEPENDENCIES
#     126     if not LIBZBAR:
# --> 127         libzbar, dependencies = zbar_library.load()
#     128         LIBZBAR = libzbar
#     129         EXTERNAL_DEPENDENCIES = [LIBZBAR] + dependencies
#
# /usr/local/lib/python3.7/dist-packages/pyzbar/zbar_library.py in load()
#      63         path = find_library('zbar')
#      64         if not path:
# ---> 65             raise ImportError('Unable to find zbar shared library')
#      66         libzbar = cdll.LoadLibrary(path)
#      67         dependencies = []
#
# ImportError: Unable to find zbar shared library
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# import cv2
# import webbrowser
# cap = cv2.VideoCapture(0)
# # initialize the cv2 QRCode detector
# detector = cv2.QRCodeDetector()
# while True:
# 	_, img = cap.read()
# # detect and decode
# data, bbox, _ = detector.detectAndDecode(img)
# # check if there is a QRCode in the image
# if data:
#   a=data
#   break
       
# cv2.imshow("QRCODEscanner", img)   
# if cv2.waitKey(1) == ord("q"):
#   break
 
# b=webbrowser.open(str(a))
# cap.release()
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f882d7cc6cf2> in <module>()
#       5 detector = cv2.QRCodeDetector()
#       6 while True:
# ----> 7         _, img = cap.read()
#       8 # detect and decode
#       9 data, bbox, _ = detector.detectAndDecode(img)
#
# KeyboardInterrupt:

# %%
#---------------------Program on the END USER to Retrieve OTP---------------------------# 
org = cv2.addWeighted(bld,2,fil,-1, 0)
cv2.imwrite('Retrieved_OTP.png', org)

# %%
import cv2
import webbrowser

cap = cv2.VideoCapture(0)
detector = cv2.QRCodeDetector()

while True:
    _,img=cap.read()
    data,one, _=detector.detectAndDecode(img)
    if data:
        a=data
        break
    cv2.imshow('qrcodescanner app',img)    
    if cv2.waitKey(1)==ord('q'):
        break
b=webbrowser.open(str(a)) 
cap.release(a)
cv2.destroyAllWindows()
